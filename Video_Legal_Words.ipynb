# %% [markdown]
# <a href="https://colab.research.google.com/github/LukasPurbaW/learn-bahasa-indonesia/blob/main/Video_Legal_Words.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Dictionary Legal Words
# This Code is used to scrap Indonesian words that are used by Indonesia Holomembers Streamer through their Youtube video's subtitle, verify the words using KBBI, and then translate it using google translate lib

# %%
# !pip -qq install youtube-transcript-api
# !pip -qq install pillow

# %%
## Video ID
#url = https://youtu.be/lL7SAjOaijw

video_id = 'lL7SAjOaijw'
thumbnail_url = "http://img.youtube.com/vi/%s/0.jpg" % video_id

#to do list 
# 1. Regex to get id from video_url
# 2. Find a way to iterate multiple video_id

# %%
import urllib.request
from PIL import Image
urllib.request.urlretrieve(thumbnail_url, 'Kobo')
img = Image.open('Kobo')
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=480x360 at 0x7F2F3C50EED0>

# %% [markdown]
# ## Extract CC from Videos

# %%
from youtube_transcript_api import YouTubeTranscriptApi
from youtube_transcript_api.formatters import JSONFormatter

formatter = JSONFormatter()
subtitle = YouTubeTranscriptApi.get_transcript(video_id,
                                          languages=['id'])

json_formatted = formatter.format_transcript(subtitle)

with open(video_id +'.json', 'w', encoding='utf-8') as json_file:
    json_file.write(json_formatted)

# %%
import pandas as pd
import json

# Use pandas.DataFrame.from_dict() to Convert JSON to DataFrame
df = pd.read_json(video_id +'.json')
df.sample(10)
# Out:
#                                          text     start  duration
# 214    sumpil eh aduh maju dikit ini nih maju   850.630     5.850
# 197                                ngapain ya   788.990     5.360
# 1086      Kita resmi menamatkan OVA 1 ya guys  3782.339     5.101
# 548                                      situ  1962.910     4.200
# 256                       yang pulang tadi ya   996.320     4.079
# 79                               ya bisa dong   374.680     2.540
# 732                                   hai hai  2647.310     3.450
# 482   Hai mainin yang cat gini-gini pasti ada  1733.270     5.060
# 545                                matematika  1953.370     7.680
# 942         oke oke Guys obyek yang juga is a  3292.170     7.080

# %% [markdown]
# ## Counting Words Frequencies

# %%
df_text = df['text']
Combined_words = df_text.str.cat(sep=' ')
Combined_words = Combined_words.lower()
Combined_words = Combined_words.split(" ")


New_dict_frequencies = {i:Combined_words.count(i) for i in Combined_words}
New_dict_frequencies

New_dict = pd.DataFrame.from_dict(New_dict_frequencies, orient='index',columns=['Frequency'])
New_dict = New_dict.sort_values(by=['Frequency'],ascending=False)
New_dict.head(10)
# Out:
#       Frequency
# hai         594
# ya          212
# ini         138
# aku         119
# guys        105
# yang         91
# udah         84
# aduh         78
# di           77
# itu          76

# %% [markdown]
# ## Searching the meaning of the words using KBBI as verifier
# (only legal Indonesian language (no slank))

# %%
# !pip -qq install kbbi

# %%
from kbbi import KBBI
#cinta = KBBI('cinta')

# !pip -qq install tqdm
from tqdm import tqdm

# %%
kbbi_url="https://raw.githubusercontent.com/bukujari/kbbi/master/assets/daftar-kata.json"
KBBI = pd.read_json(kbbi_url)
KBBI.sample(20)

# To do list
#Save the daftar-kata.json
# Out:
#                  uri        keyword
# 12968      kedangkan      Kedangkan
# 10700  infrastruktur  Infrastruktur
# 15956          lanar          Lanar
# 22515     plutokrasi     Plutokrasi
# 10445          ikram          Ikram
# 17027          lohok          Lohok
# 30879       /wilayah        Wilayah
# 30784        /waswas         Waswas
# 21195     pascalahir     Pascalahir
# 1376        anterior       Anterior
# 4659         cencang        Cencang
# 7370             erg            Erg
# 27728          suang          Suang
# 16794          likur          Likur
# 11357          jarum          Jarum
# 29822          tokek          Tokek
# 17197           luik           Luik
# 8968           germo          Germo
# 21861          pergi          Pergi
# 20063        nurbisa        Nurbisa

# %%
merged = pd.merge(New_dict, KBBI, left_index=True, right_on='uri')
del merged["keyword"]
merged = merged.set_index('uri')
merged.index.name = None
Legal_Words = merged
Legal_Words
# Out:
#        Frequency
# hai          594
# ini          138
# aku          119
# aduh          78
# di            77
# ...          ...
# cuci           1
# hebat          1
# lucah          1
# obyek          1
# man            1
#
# [755 rows x 1 columns]

# %% [markdown]
# ### Legal Words Translation

# %%
# !pip -qq install googletrans==4.0.0rc1
#testing
from googletrans import Translator
translator = Translator()
ar = translator.translate('Saya',src="id",dest="en").text
print(ar)
# Out:
# I

# %%
Vocab = Legal_Words.index[0]
ar = translator.translate(str(Vocab),src="id",dest="en").text
ar
# Out:
# 'Hi'

# %%
import numpy as np
NaN = np.nan
df = Legal_Words
df["Meaning"] = NaN
for i in range(len(df)) :
  if pd.isnull(df.iloc[i, df.columns.get_loc('Meaning')]) == True :
    try : 
      Vocab = Legal_Words.index[i]
      print("===================")
      print("Number of data :",i, "out of",len(df))
      
      print(Vocab)
      ar = translator.translate(str(Vocab),src="id",dest="en").text
      print("the translation is :", ar)
      df.iloc[i, df.columns.get_loc('Meaning')] = ar
      
    except Exception:
      pass
# Out:
# ===================
# Number of data : 0 out of 755
# hai
# the translation is : Hi
# ===================
# Number of data : 1 out of 755
# ini
# ===================
# Number of data : 2 out of 755
# aku
# the translation is : I
# ===================
# Number of data : 3 out of 755
# aduh
# the translation is : ouch
# ===================
# Number of data : 4 out of 755
# di
# the translation is : in
# ===================
# Number of data : 5 out of 755
# itu
# the translation is : that
# ===================
# Number of data : 6 out of 755
# ada
# the translation is : there is
# ===================
# Number of data : 7 out of 755
# sih
# ===================
# Number of data : 8 out of 755
# kita
# the translation is : we
# ===================
# Number of data : 9 out of 755
# oke
# the translation is : okay
# ===================
# Number of data : 10 out of 755
# apa
# the translation is : what
# ===================
# Number of data : 11 out of 755
# enggak
# the translation is : no
# ===================
# Number of data : 12 out of 755
# ah
# the translation is : Ah
# ===================
# Number of data : 13 out of 755
# kalian
# the translation is : We
# ===================
# Number of data : 14 out of 755
# mami
# the translation is : Mommy
# ===================
# Number of data : 15 out of 755
# lagi
# the translation is : again
# ===================
# Number of data : 16 out of 755
# mau
# the translation is : want to
# ===================
# Number of data : 17 out of 755
# oh
# the translation is : Oh
# ===================
# Number of data : 18 out of 755
# eh
# the translation is : Eh
# ===================
# Number of data : 19 out of 755
# mana
# the translation is : where
# ===================
# Number of data : 20 out of 755
# bisa
# the translation is : can
# ===================
# Number of data : 21 out of 755
# sini
# the translation is : here
# ===================
# Number of data : 22 out of 755
# ke
# the translation is : to
# ===================
# Number of data : 23 out of 755
# aja
# the translation is : just
# ===================
# Number of data : 24 out of 755
# tadi
# the translation is : earlier
# ===================
# Number of data : 25 out of 755
# nih
# the translation is : Here
# ===================
# Number of data : 26 out of 755
# kasih
# the translation is : love
# ===================
# Number of data : 27 out of 755
# banget
# ===================
# Number of data : 28 out of 755
# nanti
# the translation is : later
# ===================
# Number of data : 29 out of 755
# kayak
# the translation is : Like
# ===================
# Number of data : 30 out of 755
# gila
# the translation is : crazy
# ===================
# Number of data : 31 out of 755
# terus
# the translation is : Keep going
# ===================
# Number of data : 32 out of 755
# halo
# the translation is : Hello
# ===================
# Number of data : 33 out of 755
# lari
# the translation is : run
# ===================
# Number of data : 34 out of 755
# terima
# the translation is : accept
# ===================
# Number of data : 35 out of 755
# iya
# the translation is : yes
# ===================
# Number of data : 36 out of 755
# kau
# the translation is : you
# ===================
# Number of data : 37 out of 755
# kan
# the translation is : right
# ===================
# Number of data : 38 out of 755
# jadi
# the translation is : so
# ===================
# Number of data : 39 out of 755
# masih
# the translation is : still
# ===================
# Number of data : 40 out of 755
# juga
# the translation is : also
# ===================
# Number of data : 41 out of 755
# harus
# the translation is : should
# ===================
# Number of data : 42 out of 755
# tidak
# the translation is : no
# ===================
# Number of data : 43 out of 755
# kamu
# the translation is : you
# ===================
# Number of data : 44 out of 755
# tahu
# the translation is : know
# ===================
# Number of data : 45 out of 755
# kalau
# the translation is : if
# ===================
# Number of data : 46 out of 755
# nah
# the translation is : now,
# ===================
# Number of data : 47 out of 755
# atas
# the translation is : on
# ===================
# Number of data : 48 out of 755
# dulu
# the translation is : before
# ===================
# Number of data : 49 out of 755
# doang
# the translation is : doang
# ===================
# Number of data : 50 out of 755
# jangan
# ===================
# Number of data : 51 out of 755
# kok
# the translation is : how come
# ===================
# Number of data : 52 out of 755
# tapi
# the translation is : but
# ===================
# Number of data : 53 out of 755
# ih
# the translation is : IG
# ===================
# Number of data : 54 out of 755
# donasi
# ===================
# Number of data : 55 out of 755
# sekarang
# the translation is : now
# ===================
# Number of data : 56 out of 755
# takut
# the translation is : afraid
# ===================
# Number of data : 57 out of 755
# kah
# the translation is : Kah
# ===================
# Number of data : 58 out of 755
# kali
# the translation is : time
# ===================
# Number of data : 59 out of 755
# baca
# the translation is : read
# ===================
# Number of data : 60 out of 755
# dong
# the translation is : please
# ===================
# Number of data : 61 out of 755
# dari
# the translation is : from
# ===================
# Number of data : 62 out of 755
# orang
# ===================
# Number of data : 63 out of 755
# lah
# the translation is : Lah
# ===================
# Number of data : 64 out of 755
# maaf
# the translation is : excuse me
# ===================
# Number of data : 65 out of 755
# para
# the translation is : Para
# ===================
# Number of data : 66 out of 755
# sabar
# the translation is : patient
# ===================
# Number of data : 67 out of 755
# bukan
# ===================
# Number of data : 68 out of 755
# satu
# the translation is : one
# ===================
# Number of data : 69 out of 755
# sama
# the translation is : same
# ===================
# Number of data : 70 out of 755
# jam
# the translation is : o'clock
# ===================
# Number of data : 71 out of 755
# om
# the translation is : Om
# ===================
# Number of data : 72 out of 755
# ayo
# ===================
# Number of data : 73 out of 755
# pasti
# ===================
# Number of data : 74 out of 755
# tempat
# the translation is : the place
# ===================
# Number of data : 75 out of 755
# atau
# the translation is : or
# ===================
# Number of data : 76 out of 755
# sudah
# the translation is : already
# ===================
# Number of data : 77 out of 755
# siapa
# the translation is : who
# ===================
# Number of data : 78 out of 755
# lewat
# the translation is : past
# ===================
# Number of data : 79 out of 755
# apakah
# ===================
# Number of data : 80 out of 755
# permisi
# ===================
# Number of data : 81 out of 755
# sekali
# the translation is : very
# ===================
# Number of data : 82 out of 755
# kemarin
# the translation is : yesterday
# ===================
# Number of data : 83 out of 755
# deh
# ===================
# Number of data : 84 out of 755
# langsung
# the translation is : direct
# ===================
# Number of data : 85 out of 755
# dan
# the translation is : and
# ===================
# Number of data : 86 out of 755
# mungkin
# the translation is : possible
# ===================
# Number of data : 87 out of 755
# bentar
# the translation is : just a moment
# ===================
# Number of data : 88 out of 755
# pakai
# the translation is : use
# ===================
# Number of data : 89 out of 755
# astaga
# the translation is : good grief
# ===================
# Number of data : 90 out of 755
# keren
# the translation is : cool
# ===================
# Number of data : 91 out of 755
# kenapa
# ===================
# Number of data : 92 out of 755
# mati
# the translation is : dead
# ===================
# Number of data : 93 out of 755
# buka
# ===================
# Number of data : 94 out of 755
# bakal
# the translation is : will
# ===================
# Number of data : 95 out of 755
# nama
# the translation is : name
# ===================
# Number of data : 96 out of 755
# buat
# the translation is : for
# ===================
# Number of data : 97 out of 755
# pada
# the translation is : on
# ===================
# Number of data : 98 out of 755
# no
# ===================
# Number of data : 99 out of 755
# uh
# the translation is : Uh
# ===================
# Number of data : 100 out of 755
# akan
# the translation is : will
# ===================
# Number of data : 101 out of 755
# situ
# the translation is : there
# ===================
# Number of data : 102 out of 755
# si
# ===================
# Number of data : 103 out of 755
# salah
# the translation is : wrong
# ===================
# Number of data : 104 out of 755
# suka
# the translation is : like
# ===================
# Number of data : 105 out of 755
# cuman
# the translation is : only
# ===================
# Number of data : 106 out of 755
# jalan
# the translation is : Street
# ===================
# Number of data : 107 out of 755
# baterai
# the translation is : battery
# ===================
# Number of data : 108 out of 755
# lebih
# the translation is : more
# ===================
# Number of data : 109 out of 755
# i
# the translation is : i
# ===================
# Number of data : 110 out of 755
# biar
# the translation is : let
# ===================
# Number of data : 111 out of 755
# tidur
# the translation is : sleep
# ===================
# Number of data : 112 out of 755
# enak
# the translation is : nice
# ===================
# Number of data : 113 out of 755
# bogor
# the translation is : Bogor
# ===================
# Number of data : 114 out of 755
# banyak
# the translation is : many
# ===================
# Number of data : 115 out of 755
# belum
# the translation is : not yet
# ===================
# Number of data : 116 out of 755
# aman
# the translation is : safe
# ===================
# Number of data : 117 out of 755
# habis
# the translation is : finished
# ===================
# Number of data : 118 out of 755
# tamat
# the translation is : finished
# ===================
# Number of data : 119 out of 755
# dokumen
# the translation is : document
# ===================
# Number of data : 120 out of 755
# awas
# ===================
# Number of data : 121 out of 755
# ampun
# ===================
# Number of data : 122 out of 755
# hujan
# the translation is : rain
# ===================
# Number of data : 123 out of 755
# emang
# the translation is : indeed
# ===================
# Number of data : 124 out of 755
# kasihan
# the translation is : pity
# ===================
# Number of data : 125 out of 755
# cepat
# the translation is : fast
# ===================
# Number of data : 126 out of 755
# masuk
# ===================
# Number of data : 127 out of 755
# boleh
# the translation is : can
# ===================
# Number of data : 128 out of 755
# saya
# the translation is : I
# ===================
# Number of data : 129 out of 755
# tenang
# the translation is : calm
# ===================
# Number of data : 130 out of 755
# kurang
# the translation is : not enough
# ===================
# Number of data : 131 out of 755
# kesel
# the translation is : annoyed
# ===================
# Number of data : 132 out of 755
# hari
# ===================
# Number of data : 133 out of 755
# tinggal
# the translation is : Live
# ===================
# Number of data : 134 out of 755
# kupu
# ===================
# Number of data : 135 out of 755
# coba
# the translation is : try
# ===================
# Number of data : 136 out of 755
# suruh
# ===================
# Number of data : 137 out of 755
# karena
# the translation is : because
# ===================
# Number of data : 138 out of 755
# lihat
# the translation is : see
# ===================
# Number of data : 139 out of 755
# pula
# the translation is : also
# ===================
# Number of data : 140 out of 755
# gua
# ===================
# Number of data : 141 out of 755
# dengan
# the translation is : with
# ===================
# Number of data : 142 out of 755
# bawah
# the translation is : lower
# ===================
# Number of data : 143 out of 755
# benar
# the translation is : correct
# ===================
# Number of data : 144 out of 755
# malam
# the translation is : night
# ===================
# Number of data : 145 out of 755
# jendela
# the translation is : window
# ===================
# Number of data : 146 out of 755
# maju
# the translation is : proceed
# ===================
# Number of data : 147 out of 755
# ama
# the translation is : ama
# ===================
# Number of data : 148 out of 755
# semua
# the translation is : all
# ===================
# Number of data : 149 out of 755
# tak
# ===================
# Number of data : 150 out of 755
# biru
# the translation is : blue
# ===================
# Number of data : 151 out of 755
# berapa
# the translation is : how many
# ===================
# Number of data : 152 out of 755
# papa
# ===================
# Number of data : 153 out of 755
# a
# the translation is : a
# ===================
# Number of data : 154 out of 755
# main
# the translation is : play
# ===================
# Number of data : 155 out of 755
# rekam
# the translation is : Record
# ===================
# Number of data : 156 out of 755
# loh
# ===================
# Number of data : 157 out of 755
# kuning
# the translation is : yellow
# ===================
# Number of data : 158 out of 755
# balik
# the translation is : come back
# ===================
# Number of data : 159 out of 755
# n
# the translation is : n
# ===================
# Number of data : 160 out of 755
# tuhan
# the translation is : lord
# ===================
# Number of data : 161 out of 755
# pergi
# the translation is : go
# ===================
# Number of data : 162 out of 755
# lu
# the translation is : Lu
# ===================
# Number of data : 163 out of 755
# terlalu
# the translation is : too
# ===================
# Number of data : 164 out of 755
# monster
# the translation is : Monster
# ===================
# Number of data : 165 out of 755
# gue
# the translation is : I
# ===================
# Number of data : 166 out of 755
# protagonis
# the translation is : protagonist
# ===================
# Number of data : 167 out of 755
# sekalian
# ===================
# Number of data : 168 out of 755
# dalam
# ===================
# Number of data : 169 out of 755
# indonesia
# the translation is : Indonesia
# ===================
# Number of data : 170 out of 755
# dapur
# the translation is : kitchen
# ===================
# Number of data : 171 out of 755
# mi
# the translation is : Mi
# ===================
# Number of data : 172 out of 755
# ulang
# the translation is : repeat
# ===================
# Number of data : 173 out of 755
# budak
# the translation is : slave
# ===================
# Number of data : 174 out of 755
# mama
# the translation is : Mama
# ===================
# Number of data : 175 out of 755
# keluar
# the translation is : go out
# ===================
# Number of data : 176 out of 755
# naik
# the translation is : go on
# ===================
# Number of data : 177 out of 755
# putar
# the translation is : play
# ===================
# Number of data : 178 out of 755
# pernah
# the translation is : once
# ===================
# Number of data : 179 out of 755
# tangga
# ===================
# Number of data : 180 out of 755
# istimewa
# the translation is : special
# ===================
# Number of data : 181 out of 755
# makan
# ===================
# Number of data : 182 out of 755
# kanan
# the translation is : right
# ===================
# Number of data : 183 out of 755
# kiri
# the translation is : left
# ===================
# Number of data : 184 out of 755
# selesai
# the translation is : done
# ===================
# Number of data : 185 out of 755
# biasa
# the translation is : normal
# ===================
# Number of data : 186 out of 755
# kirim
# the translation is : send
# ===================
# Number of data : 187 out of 755
# tolong
# the translation is : help
# ===================
# Number of data : 188 out of 755
# ia
# the translation is : he
# ===================
# Number of data : 189 out of 755
# foto
# the translation is : photo
# ===================
# Number of data : 190 out of 755
# pas
# the translation is : right
# ===================
# Number of data : 191 out of 755
# dia
# the translation is : he
# ===================
# Number of data : 192 out of 755
# banting
# the translation is : slam
# ===================
# Number of data : 193 out of 755
# galon
# the translation is : gallon
# ===================
# Number of data : 194 out of 755
# hi
# the translation is : Hi
# ===================
# Number of data : 195 out of 755
# mantra
# the translation is : Mantra
# ===================
# Number of data : 196 out of 755
# kata
# the translation is : say
# ===================
# Number of data : 197 out of 755
# cinta
# the translation is : love
# ===================
# Number of data : 198 out of 755
# sesuatu
# the translation is : something
# ===================
# Number of data : 199 out of 755
# tahan
# the translation is : stand
# ===================
# Number of data : 200 out of 755
# ceplas-ceplos
# the translation is : frankly
# ===================
# Number of data : 201 out of 755
# anak
# the translation is : child
# ===================
# Number of data : 202 out of 755
# kamera
# the translation is : camera
# ===================
# Number of data : 203 out of 755
# mata
# the translation is : eye
# ===================
# Number of data : 204 out of 755
# siap
# the translation is : ready
# ===================
# Number of data : 205 out of 755
# kui
# the translation is : My i
# ===================
# Number of data : 206 out of 755
# nomor
# the translation is : number
# ===================
# Number of data : 207 out of 755
# bacot
# the translation is : Too much talking
# ===================
# Number of data : 208 out of 755
# rumah
# the translation is : House
# ===================
# Number of data : 209 out of 755
# muhammad
# the translation is : Muhammad
# ===================
# Number of data : 210 out of 755
# sangat
# the translation is : very
# ===================
# Number of data : 211 out of 755
# kunjung
# the translation is : visit
# ===================
# Number of data : 212 out of 755
# teh
# the translation is : tea
# ===================
# Number of data : 213 out of 755
# jauh
# the translation is : far
# ===================
# Number of data : 214 out of 755
# tau
# the translation is : know
# ===================
# Number of data : 215 out of 755
# bang
# the translation is : Bang
# ===================
# Number of data : 216 out of 755
# sebentar
# the translation is : a moment
# ===================
# Number of data : 217 out of 755
# gajah
# the translation is : elephant
# ===================
# Number of data : 218 out of 755
# mbak
# the translation is : miss
# ===================
# Number of data : 219 out of 755
# ibu
# the translation is : Mother
# ===================
# Number of data : 220 out of 755
# bohong
# the translation is : lie
# ===================
# Number of data : 221 out of 755
# betul
# the translation is : right
# ===================
# Number of data : 222 out of 755
# cantik
# the translation is : beautiful
# ===================
# Number of data : 223 out of 755
# saat
# the translation is : moment
# ===================
# Number of data : 224 out of 755
# beda
# the translation is : different
# ===================
# Number of data : 225 out of 755
# bu
# the translation is : Ma'am
# ===================
# Number of data : 226 out of 755
# baru
# the translation is : new
# ===================
# Number of data : 227 out of 755
# awal
# the translation is : beginning
# ===================
# Number of data : 228 out of 755
# puji
# the translation is : Praise
# ===================
# Number of data : 229 out of 755
# mah
# the translation is : mah
# ===================
# Number of data : 230 out of 755
# pintu
# the translation is : door
# ===================
# Number of data : 231 out of 755
# salam
# the translation is : regards
# ===================
# Number of data : 232 out of 755
# tunggu
# the translation is : wait
# ===================
# Number of data : 233 out of 755
# entar
# the translation is : later
# ===================
# Number of data : 234 out of 755
# cari
# the translation is : search
# ===================
# Number of data : 235 out of 755
# aneh
# the translation is : strange
# ===================
# Number of data : 236 out of 755
# besok
# the translation is : tomorrow
# ===================
# Number of data : 237 out of 755
# suara
# the translation is : voice
# ===================
# Number of data : 238 out of 755
# bagaimana
# the translation is : how
# ===================
# Number of data : 239 out of 755
# singkat
# the translation is : short
# ===================
# Number of data : 240 out of 755
# nyah
# the translation is : Nyah
# ===================
# Number of data : 241 out of 755
# panjang
# the translation is : long
# ===================
# Number of data : 242 out of 755
# air
# the translation is : water
# ===================
# Number of data : 243 out of 755
# debut
# the translation is : debut
# ===================
# Number of data : 244 out of 755
# kunci
# the translation is : key
# ===================
# Number of data : 245 out of 755
# turun
# the translation is : down
# ===================
# Number of data : 246 out of 755
# bobok
# the translation is : sleep
# ===================
# Number of data : 247 out of 755
# cuma
# the translation is : only
# ===================
# Number of data : 248 out of 755
# daging
# the translation is : meat
# ===================
# Number of data : 249 out of 755
# punya
# the translation is : have
# ===================
# Number of data : 250 out of 755
# mertua
# the translation is : parents in law
# ===================
# Number of data : 251 out of 755
# perlu
# the translation is : need
# ===================
# Number of data : 252 out of 755
# saja
# the translation is : just
# ===================
# Number of data : 253 out of 755
# seperti
# the translation is : as
# ===================
# Number of data : 254 out of 755
# yuk
# the translation is : Come on
# ===================
# Number of data : 255 out of 755
# yuk
# the translation is : Come on
# ===================
# Number of data : 256 out of 755
# beli
# the translation is : buy
# ===================
# Number of data : 257 out of 755
# senang
# the translation is : happy
# ===================
# Number of data : 258 out of 755
# selamat
# the translation is : safe
# ===================
# Number of data : 259 out of 755
# pagi
# the translation is : morning
# ===================
# Number of data : 260 out of 755
# otot
# the translation is : muscle
# ===================
# Number of data : 261 out of 755
# barusan
# the translation is : just now
# ===================
# Number of data : 262 out of 755
# teman
# the translation is : friend
# ===================
# Number of data : 263 out of 755
# tanpa
# the translation is : without
# ===================
# Number of data : 264 out of 755
# malah
# the translation is : rather
# ===================
# Number of data : 265 out of 755
# sigma
# the translation is : Sigma
# ===================
# Number of data : 266 out of 755
# anda
# the translation is : you
# ===================
# Number of data : 267 out of 755
# tinggi
# the translation is : tall
# ===================
# Number of data : 268 out of 755
# sebut
# the translation is : Call
# ===================
# Number of data : 269 out of 755
# over
# the translation is : Over
# ===================
# Number of data : 270 out of 755
# tukang
# the translation is : craftsman
# ===================
# Number of data : 271 out of 755
# suci
# the translation is : holy
# ===================
# Number of data : 272 out of 755
# neng
# the translation is : Neng
# ===================
# Number of data : 273 out of 755
# hamba
# the translation is : servant
# ===================
# Number of data : 274 out of 755
# jual
# the translation is : sell
# ===================
# Number of data : 275 out of 755
# setan
# the translation is : Devil
# ===================
# Number of data : 276 out of 755
# pupuk
# the translation is : fertilizer
# ===================
# Number of data : 277 out of 755
# pi
# the translation is : Pi
# ===================
# Number of data : 278 out of 755
# to
# the translation is : TO
# ===================
# Number of data : 279 out of 755
# misi
# the translation is : mission
# ===================
# Number of data : 280 out of 755
# be
# the translation is : be
# ===================
# Number of data : 281 out of 755
# nia
# the translation is : Nia
# ===================
# Number of data : 282 out of 755
# minum
# the translation is : drink
# ===================
# Number of data : 283 out of 755
# muka
# the translation is : advance
# ===================
# Number of data : 284 out of 755
# cat
# the translation is : paint
# ===================
# Number of data : 285 out of 755
# putih
# the translation is : white
# ===================
# Number of data : 286 out of 755
# begini
# the translation is : Look
# ===================
# Number of data : 287 out of 755
# lo
# the translation is : Lo
# ===================
# Number of data : 288 out of 755
# dunia
# the translation is : world
# ===================
# Number of data : 289 out of 755
# canda
# the translation is : joke
# ===================
# Number of data : 290 out of 755
# kawan
# the translation is : friend
# ===================
# Number of data : 291 out of 755
# silau
# the translation is : dazzled
# ===================
# Number of data : 292 out of 755
# butuh
# the translation is : need
# ===================
# Number of data : 293 out of 755
# durhaka
# the translation is : ungodly
# ===================
# Number of data : 294 out of 755
# bapak
# the translation is : father
# ===================
# Number of data : 295 out of 755
# kambing
# the translation is : goat
# ===================
# Number of data : 296 out of 755
# sendiri
# the translation is : alone
# ===================
# Number of data : 297 out of 755
# betapa
# the translation is : how
# ===================
# Number of data : 298 out of 755
# bad
# the translation is : Bad
# ===================
# Number of data : 299 out of 755
# lancar
# the translation is : fluent
# ===================
# Number of data : 300 out of 755
# baik
# the translation is : good
# ===================
# Number of data : 301 out of 755
# lima
# the translation is : five
# ===================
# Number of data : 302 out of 755
# bubar
# the translation is : Disband
# ===================
# Number of data : 303 out of 755
# generator
# the translation is : generator
# ===================
# Number of data : 304 out of 755
# ayah
# the translation is : father
# ===================
# Number of data : 305 out of 755
# kosong
# the translation is : blank
# ===================
# Number of data : 306 out of 755
# kongres
# the translation is : congress
# ===================
# Number of data : 307 out of 755
# kalo
# the translation is : if
# ===================
# Number of data : 308 out of 755
# celah
# the translation is : gap
# ===================
# Number of data : 309 out of 755
# bangun
# the translation is : Wake up
# ===================
# Number of data : 310 out of 755
# begitu
# the translation is : so
# ===================
# Number of data : 311 out of 755
# hingga
# the translation is : until
# ===================
# Number of data : 312 out of 755
# bersih
# the translation is : clean
# ===================
# Number of data : 313 out of 755
# sabtu
# the translation is : Saturday
# ===================
# Number of data : 314 out of 755
# rusak
# the translation is : damaged
# ===================
# Number of data : 315 out of 755
# ambil
# the translation is : take
# ===================
# Number of data : 316 out of 755
# layer
# the translation is : Layer
# ===================
# Number of data : 317 out of 755
# m
# the translation is : m
# ===================
# Number of data : 318 out of 755
# lawan
# the translation is : opponent
# ===================
# Number of data : 319 out of 755
# hanya
# the translation is : only
# ===================
# Number of data : 320 out of 755
# sedang
# the translation is : currently
# ===================
# Number of data : 321 out of 755
# item
# the translation is : item
# ===================
# Number of data : 322 out of 755
# sedikit
# the translation is : a little
# ===================
# Number of data : 323 out of 755
# koboi
# the translation is : cowboy
# ===================
# Number of data : 324 out of 755
# hitam
# the translation is : black
# ===================
# Number of data : 325 out of 755
# ketik
# the translation is : type
# ===================
# Number of data : 326 out of 755
# siang
# the translation is : afternoon
# ===================
# Number of data : 327 out of 755
# allah
# the translation is : God
# ===================
# Number of data : 328 out of 755
# soto
# the translation is : Soto
# ===================
# Number of data : 329 out of 755
# opal
# the translation is : opal
# ===================
# Number of data : 330 out of 755
# seri
# the translation is : series
# ===================
# Number of data : 331 out of 755
# macam
# the translation is : type
# ===================
# Number of data : 332 out of 755
# teori
# the translation is : theory
# ===================
# Number of data : 333 out of 755
# ranai
# the translation is : ranai
# ===================
# Number of data : 334 out of 755
# lupa
# the translation is : forget
# ===================
# Number of data : 335 out of 755
# menang
# the translation is : win
# ===================
# Number of data : 336 out of 755
# jago
# the translation is : champion
# ===================
# Number of data : 337 out of 755
# tentang
# the translation is : about
# ===================
# Number of data : 338 out of 755
# titip
# the translation is : entrusted
# ===================
# Number of data : 339 out of 755
# jatuh
# the translation is : fall
# ===================
# Number of data : 340 out of 755
# nyonya
# the translation is : Mrs
# ===================
# Number of data : 341 out of 755
# amanah
# the translation is : Amanah
# ===================
# Number of data : 342 out of 755
# muncul
# the translation is : appear
# ===================
# Number of data : 343 out of 755
# adalah
# the translation is : is
# ===================
# Number of data : 344 out of 755
# sampai
# the translation is : until
# ===================
# Number of data : 345 out of 755
# sumpah
# the translation is : oath
# ===================
# Number of data : 346 out of 755
# amat
# the translation is : very
# ===================
# Number of data : 347 out of 755
# kubur
# the translation is : tomb
# ===================
# Number of data : 348 out of 755
# presiden
# the translation is : president
# ===================
# Number of data : 349 out of 755
# hadirin
# the translation is : audience
# ===================
# Number of data : 350 out of 755
# bilang
# the translation is : said
# ===================
# Number of data : 351 out of 755
# teater
# the translation is : theater
# ===================
# Number of data : 352 out of 755
# gorden
# the translation is : curtain
# ===================
# Number of data : 353 out of 755
# isi
# the translation is : Fill
# ===================
# Number of data : 354 out of 755
# lift
# the translation is : elevator
# ===================
# Number of data : 355 out of 755
# on
# the translation is : On
# ===================
# Number of data : 356 out of 755
# jelas
# the translation is : clear
# ===================
# Number of data : 357 out of 755
# gede
# the translation is : big
# ===================
# Number of data : 358 out of 755
# dikit
# the translation is : little
# ===================
# Number of data : 359 out of 755
# marine
# the translation is : Marine
# ===================
# Number of data : 360 out of 755
# sering
# the translation is : often
# ===================
# Number of data : 361 out of 755
# oleh
# the translation is : by
# ===================
# Number of data : 362 out of 755
# loncat
# the translation is : jump
# ===================
# Number of data : 363 out of 755
# masalah
# the translation is : problem
# ===================
# Number of data : 364 out of 755
# dua
# the translation is : two
# ===================
# Number of data : 365 out of 755
# merah
# the translation is : red
# ===================
# Number of data : 366 out of 755
# depan
# the translation is : front
# ===================
# Number of data : 367 out of 755
# ha
# the translation is : Ha
# ===================
# Number of data : 368 out of 755
# kami
# the translation is : we
# ===================
# Number of data : 369 out of 755
# kangen
# the translation is : miss
# ===================
# Number of data : 370 out of 755
# sempurna
# the translation is : perfect
# ===================
# Number of data : 371 out of 755
# kelap-kelip
# the translation is : twinkling
# ===================
# Number of data : 372 out of 755
# dagu
# the translation is : chin
# ===================
# Number of data : 373 out of 755
# suasana
# the translation is : atmosphere
# ===================
# Number of data : 374 out of 755
# biji
# the translation is : seed
# ===================
# Number of data : 375 out of 755
# kubu
# the translation is : camp
# ===================
# Number of data : 376 out of 755
# memang
# the translation is : of course
# ===================
# Number of data : 377 out of 755
# ponco
# the translation is : Ponco
# ===================
# Number of data : 378 out of 755
# laut
# the translation is : Sea
# ===================
# Number of data : 379 out of 755
# oma
# the translation is : Oma
# ===================
# Number of data : 380 out of 755
# beri
# the translation is : Give
# ===================
# Number of data : 381 out of 755
# sosok
# the translation is : figure
# ===================
# Number of data : 382 out of 755
# fatah
# the translation is : Fatah
# ===================
# Number of data : 383 out of 755
# antara
# the translation is : Among
# ===================
# Number of data : 384 out of 755
# tanya
# the translation is : ask
# ===================
# Number of data : 385 out of 755
# salat
# the translation is : Salat
# ===================
# Number of data : 386 out of 755
# buah
# the translation is : fruit
# ===================
# Number of data : 387 out of 755
# masing-masing
# the translation is : each
# ===================
# Number of data : 388 out of 755
# capek
# the translation is : tired
# ===================
# Number of data : 389 out of 755
# raya
# the translation is : Raya
# ===================
# Number of data : 390 out of 755
# ide
# the translation is : idea
# ===================
# Number of data : 391 out of 755
# spekulasi
# the translation is : speculation
# ===================
# Number of data : 392 out of 755
# total
# the translation is : total
# ===================
# Number of data : 393 out of 755
# t
# the translation is : t
# ===================
# Number of data : 394 out of 755
# macan
# the translation is : tiger
# ===================
# Number of data : 395 out of 755
# deras
# the translation is : heavy
# ===================
# Number of data : 396 out of 755
# plus
# the translation is : plus
# ===================
# Number of data : 397 out of 755
# batal
# the translation is : cancelled
# ===================
# Number of data : 398 out of 755
# telor
# the translation is : Egg
# ===================
# Number of data : 399 out of 755
# robot
# the translation is : robot
# ===================
# Number of data : 400 out of 755
# hoki
# the translation is : hockey
# ===================
# Number of data : 401 out of 755
# senyum
# the translation is : smile
# ===================
# Number of data : 402 out of 755
# am
# the translation is : Am
# ===================
# Number of data : 403 out of 755
# kuah
# the translation is : broth
# ===================
# Number of data : 404 out of 755
# asyik
# the translation is : fun
# ===================
# Number of data : 405 out of 755
# kelas
# the translation is : class
# ===================
# Number of data : 406 out of 755
# episode
# the translation is : episode
# ===================
# Number of data : 407 out of 755
# solar
# the translation is : Solar
# ===================
# Number of data : 408 out of 755
# produk
# the translation is : product
# ===================
# Number of data : 409 out of 755
# koleksi
# the translation is : collection
# ===================
# Number of data : 410 out of 755
# nyawa
# the translation is : life
# ===================
# Number of data : 411 out of 755
# ialah
# the translation is : is
# ===================
# Number of data : 412 out of 755
# tanggal
# the translation is : date
# ===================
# Number of data : 413 out of 755
# sehingga
# the translation is : so that
# ===================
# Number of data : 414 out of 755
# dadah
# the translation is : dadah
# ===================
# Number of data : 415 out of 755
# proyek
# the translation is : project
# ===================
# Number of data : 416 out of 755
# mura
# the translation is : Mura
# ===================
# Number of data : 417 out of 755
# cahaya
# the translation is : light
# ===================
# Number of data : 418 out of 755
# kerupuk
# the translation is : shrimp crisp
# ===================
# Number of data : 419 out of 755
# ihwal
# the translation is : about
# ===================
# Number of data : 420 out of 755
# sesi
# the translation is : session
# ===================
# Number of data : 421 out of 755
# gita
# the translation is : Gita
# ===================
# Number of data : 422 out of 755
# ampuh
# the translation is : effective
# ===================
# Number of data : 423 out of 755
# nasi
# the translation is : rice
# ===================
# Number of data : 424 out of 755
# bakso
# the translation is : meatball
# ===================
# Number of data : 425 out of 755
# norak
# the translation is : uncouth
# ===================
# Number of data : 426 out of 755
# cerita
# the translation is : story
# ===================
# Number of data : 427 out of 755
# maut
# the translation is : death
# ===================
# Number of data : 428 out of 755
# tengah
# the translation is : middle
# ===================
# Number of data : 429 out of 755
# rileks
# the translation is : Relax
# ===================
# Number of data : 430 out of 755
# alami
# the translation is : experience
# ===================
# Number of data : 431 out of 755
# rumen
# the translation is : rumen
# ===================
# Number of data : 432 out of 755
# inti
# the translation is : core
# ===================
# Number of data : 433 out of 755
# demokrasi
# the translation is : democracy
# ===================
# Number of data : 434 out of 755
# agak
# the translation is : rather
# ===================
# Number of data : 435 out of 755
# tim
# the translation is : team
# ===================
# Number of data : 436 out of 755
# saku
# the translation is : pocket
# ===================
# Number of data : 437 out of 755
# manusiawi
# the translation is : human
# ===================
# Number of data : 438 out of 755
# dengar
# the translation is : hear
# ===================
# Number of data : 439 out of 755
# mutiara
# the translation is : pearl
# ===================
# Number of data : 440 out of 755
# asing
# the translation is : foreign
# ===================
# Number of data : 441 out of 755
# lagu
# the translation is : song
# ===================
# Number of data : 442 out of 755
# karaoke
# the translation is : karaoke
# ===================
# Number of data : 443 out of 755
# dah
# the translation is : Bye
# ===================
# Number of data : 444 out of 755
# sang
# the translation is : the
# ===================
# Number of data : 445 out of 755
# pai
# the translation is : pie
# ===================
# Number of data : 446 out of 755
# pesanggrahan
# the translation is : Pesanggrahan
# ===================
# Number of data : 447 out of 755
# kepiting
# the translation is : crab
# ===================
# Number of data : 448 out of 755
# pantat
# the translation is : butt
# ===================
# Number of data : 449 out of 755
# bayi
# the translation is : baby
# ===================
# Number of data : 450 out of 755
# jerigen
# the translation is : jerry can
# ===================
# Number of data : 451 out of 755
# z
# the translation is : Z.
# ===================
# Number of data : 452 out of 755
# z
# the translation is : Z.
# ===================
# Number of data : 453 out of 755
# rambut
# the translation is : hair
# ===================
# Number of data : 454 out of 755
# toko
# the translation is : shop
# ===================
# Number of data : 455 out of 755
# sana
# the translation is : there
# ===================
# Number of data : 456 out of 755
# nanda
# the translation is : Nanda
# ===================
# Number of data : 457 out of 755
# fiksi
# the translation is : fiction
# ===================
# Number of data : 458 out of 755
# bening
# the translation is : clear
# ===================
# Number of data : 459 out of 755
# jawab
# the translation is : answer
# ===================
# Number of data : 460 out of 755
# ganteng
# the translation is : handsome
# ===================
# Number of data : 461 out of 755
# syair
# the translation is : poetry
# ===================
# Number of data : 462 out of 755
# kisah
# the translation is : story
# ===================
# Number of data : 463 out of 755
# tanah
# the translation is : land
# ===================
# Number of data : 464 out of 755
# tumben
# the translation is : surprise
# ===================
# Number of data : 465 out of 755
# keripik
# the translation is : chips
# ===================
# Number of data : 466 out of 755
# klarifikasi
# the translation is : clarification
# ===================
# Number of data : 467 out of 755
# karir
# the translation is : career
# ===================
# Number of data : 468 out of 755
# pecah
# the translation is : broken
# ===================
# Number of data : 469 out of 755
# kasar
# the translation is : Rough
# ===================
# Number of data : 470 out of 755
# apel
# the translation is : Apple
# ===================
# Number of data : 471 out of 755
# dada
# the translation is : chest
# ===================
# Number of data : 472 out of 755
# injak
# the translation is : stepping
# ===================
# Number of data : 473 out of 755
# marah
# the translation is : angry
# ===================
# Number of data : 474 out of 755
# geli
# the translation is : amused
# ===================
# Number of data : 475 out of 755
# komikus
# the translation is : Comicus
# ===================
# Number of data : 476 out of 755
# miniatur
# the translation is : miniature
# ===================
# Number of data : 477 out of 755
# duh
# the translation is : Duh
# ===================
# Number of data : 478 out of 755
# jumbo
# the translation is : Jumbo
# ===================
# Number of data : 479 out of 755
# goreng
# the translation is : fry
# ===================
# Number of data : 480 out of 755
# nyata
# the translation is : real
# ===================
# Number of data : 481 out of 755
# agar
# the translation is : so that
# ===================
# Number of data : 482 out of 755
# final
# the translation is : Final
# ===================
# Number of data : 483 out of 755
# merek
# the translation is : brand
# ===================
# Number of data : 484 out of 755
# saudagar
# the translation is : merchant
# ===================
# Number of data : 485 out of 755
# apalagi
# the translation is : especially
# ===================
# Number of data : 486 out of 755
# pikir
# the translation is : think
# ===================
# Number of data : 487 out of 755
# payung
# the translation is : umbrella
# ===================
# Number of data : 488 out of 755
# ramai
# the translation is : crowded
# ===================
# Number of data : 489 out of 755
# alias
# the translation is : alias
# ===================
# Number of data : 490 out of 755
# mak
# the translation is : Mak
# ===================
# Number of data : 491 out of 755
# terjun
# the translation is : plunge
# ===================
# Number of data : 492 out of 755
# lapak
# the translation is : stall
# ===================
# Number of data : 493 out of 755
# tugas
# the translation is : Duty
# ===================
# Number of data : 494 out of 755
# kebal
# the translation is : immune
# ===================
# Number of data : 495 out of 755
# mental
# the translation is : mental
# ===================
# Number of data : 496 out of 755
# kupu-kupu
# the translation is : butterfly
# ===================
# Number of data : 497 out of 755
# asal
# the translation is : origin
# ===================
# Number of data : 498 out of 755
# dimensi
# the translation is : dimensions
# ===================
# Number of data : 499 out of 755
# gadis
# the translation is : girl
# ===================
# Number of data : 500 out of 755
# janji
# the translation is : promise
# ===================
# Number of data : 501 out of 755
# sore
# the translation is : afternoon
# ===================
# Number of data : 502 out of 755
# kepada
# the translation is : to
# ===================
# Number of data : 503 out of 755
# motor
# the translation is : motorcycle
# ===================
# Number of data : 504 out of 755
# ganda
# the translation is : double
# ===================
# Number of data : 505 out of 755
# tipis
# the translation is : thin
# ===================
# Number of data : 506 out of 755
# kumis
# the translation is : moustache
# ===================
# Number of data : 507 out of 755
# peduli
# the translation is : care
# ===================
# Number of data : 508 out of 755
# jajan
# the translation is : snacking
# ===================
# Number of data : 509 out of 755
# kaya
# the translation is : rich
# ===================
# Number of data : 510 out of 755
# jeruk
# the translation is : orange
# ===================
# Number of data : 511 out of 755
# nipis
# the translation is : Line
# ===================
# Number of data : 512 out of 755
# gatal
# the translation is : itch
# ===================
# Number of data : 513 out of 755
# diam
# the translation is : silent
# ===================
# Number of data : 514 out of 755
# ancuk
# the translation is : ancuk
# ===================
# Number of data : 515 out of 755
# beliau
# the translation is : he
# ===================
# Number of data : 516 out of 755
# lama
# the translation is : long
# ===================
# Number of data : 517 out of 755
# sekolah
# the translation is : school
# ===================
# Number of data : 518 out of 755
# sing
# the translation is : Sing
# ===================
# Number of data : 519 out of 755
# mamik
# the translation is : Mamik
# ===================
# Number of data : 520 out of 755
# latih
# the translation is : Train
# ===================
# Number of data : 521 out of 755
# akhir
# the translation is : end
# ===================
# Number of data : 522 out of 755
# segar
# the translation is : fresh
# ===================
# Number of data : 523 out of 755
# tumor
# the translation is : tumor
# ===================
# Number of data : 524 out of 755
# kapan
# the translation is : when
# ===================
# Number of data : 525 out of 755
# master
# the translation is : master
# ===================
# Number of data : 526 out of 755
# tekan
# the translation is : press
# ===================
# Number of data : 527 out of 755
# do
# the translation is : Do
# ===================
# Number of data : 528 out of 755
# are
# the translation is : are
# ===================
# Number of data : 529 out of 755
# minta
# the translation is : ask for
# ===================
# Number of data : 530 out of 755
# bikin
# the translation is : make
# ===================
# Number of data : 531 out of 755
# tanda
# the translation is : sign
# ===================
# Number of data : 532 out of 755
# seru
# the translation is : exciting
# ===================
# Number of data : 533 out of 755
# bawa
# the translation is : bring
# ===================
# Number of data : 534 out of 755
# tanjung
# the translation is : cape
# ===================
# Number of data : 535 out of 755
# rame
# the translation is : Rame
# ===================
# Number of data : 536 out of 755
# agen
# the translation is : agent
# ===================
# Number of data : 537 out of 755
# suram
# the translation is : gloomy
# ===================
# Number of data : 538 out of 755
# mobil
# the translation is : car
# ===================
# Number of data : 539 out of 755
# jika
# the translation is : if
# ===================
# Number of data : 540 out of 755
# jodoh
# the translation is : partner
# ===================
# Number of data : 541 out of 755
# bopeng
# the translation is : pockmarked
# ===================
# Number of data : 542 out of 755
# ingin
# the translation is : want
# ===================
# Number of data : 543 out of 755
# tante
# the translation is : aunt
# ===================
# Number of data : 544 out of 755
# berat
# the translation is : heavy
# ===================
# Number of data : 545 out of 755
# angah
# the translation is : Angah
# ===================
# Number of data : 546 out of 755
# mam
# the translation is : Mam
# ===================
# Number of data : 547 out of 755
# jamur
# the translation is : mold
# ===================
# Number of data : 548 out of 755
# putri
# the translation is : daughter
# ===================
# Number of data : 549 out of 755
# hantu
# the translation is : ghost
# ===================
# Number of data : 550 out of 755
# luar
# the translation is : outside
# ===================
# Number of data : 551 out of 755
# rusuk
# the translation is : lateral
# ===================
# Number of data : 552 out of 755
# hilang
# the translation is : is lost
# ===================
# Number of data : 553 out of 755
# berisik
# the translation is : noisy
# ===================
# Number of data : 554 out of 755
# kuningan
# the translation is : brass
# ===================
# Number of data : 555 out of 755
# kue
# the translation is : cake
# ===================
# Number of data : 556 out of 755
# guru
# the translation is : teacher
# ===================
# Number of data : 557 out of 755
# timur
# the translation is : east
# ===================
# Number of data : 558 out of 755
# pause
# the translation is : Pause
# ===================
# Number of data : 559 out of 755
# bunuh
# the translation is : kill
# ===================
# Number of data : 560 out of 755
# sport
# the translation is : sport
# ===================
# Number of data : 561 out of 755
# sesuai
# the translation is : in accordance
# ===================
# Number of data : 562 out of 755
# toilet
# the translation is : toilet
# ===================
# Number of data : 563 out of 755
# dewasa
# the translation is : mature
# ===================
# Number of data : 564 out of 755
# plural
# the translation is : plural
# ===================
# Number of data : 565 out of 755
# keburu
# the translation is : hurried
# ===================
# Number of data : 566 out of 755
# besar
# the translation is : big
# ===================
# Number of data : 567 out of 755
# kecil
# the translation is : small
# ===================
# Number of data : 568 out of 755
# sembelit
# the translation is : constipation
# ===================
# Number of data : 569 out of 755
# atmosfer
# the translation is : atmosphere
# ===================
# Number of data : 570 out of 755
# partai
# the translation is : party
# ===================
# Number of data : 571 out of 755
# cidomo
# the translation is : Cidomo
# ===================
# Number of data : 572 out of 755
# model
# the translation is : model
# ===================
# Number of data : 573 out of 755
# entah
# the translation is : who knows
# ===================
# Number of data : 574 out of 755
# insan
# the translation is : human
# ===================
# Number of data : 575 out of 755
# jir
# the translation is : jir
# ===================
# Number of data : 576 out of 755
# pasta
# the translation is : pasta
# ===================
# Number of data : 577 out of 755
# gigi
# the translation is : tooth
# ===================
# Number of data : 578 out of 755
# tiba-tiba
# the translation is : suddenly
# ===================
# Number of data : 579 out of 755
# zaman
# the translation is : era
# ===================
# Number of data : 580 out of 755
# zaman
# the translation is : era
# ===================
# Number of data : 581 out of 755
# tepat
# the translation is : appropriate
# ===================
# Number of data : 582 out of 755
# angga
# the translation is : Angga
# ===================
# Number of data : 583 out of 755
# paus
# the translation is : Pope
# ===================
# Number of data : 584 out of 755
# sesat
# the translation is : misguided
# ===================
# Number of data : 585 out of 755
# laboratorium
# the translation is : laboratory
# ===================
# Number of data : 586 out of 755
# sembunyi
# the translation is : hide
# ===================
# Number of data : 587 out of 755
# fasih
# the translation is : fluent
# ===================
# Number of data : 588 out of 755
# ganggu
# the translation is : disturb
# ===================
# Number of data : 589 out of 755
# musik
# the translation is : music
# ===================
# Number of data : 590 out of 755
# layak
# the translation is : worthy
# ===================
# Number of data : 591 out of 755
# cara
# the translation is : method
# ===================
# Number of data : 592 out of 755
# gereja
# the translation is : church
# ===================
# Number of data : 593 out of 755
# paket
# the translation is : package
# ===================
# Number of data : 594 out of 755
# damai
# the translation is : peace
# ===================
# Number of data : 595 out of 755
# minyak
# the translation is : oil
# ===================
# Number of data : 596 out of 755
# jaka
# the translation is : Jaka
# ===================
# Number of data : 597 out of 755
# huh
# the translation is : Huh
# ===================
# Number of data : 598 out of 755
# fisika
# the translation is : physics
# ===================
# Number of data : 599 out of 755
# punah
# the translation is : extinct
# ===================
# Number of data : 600 out of 755
# bumi
# the translation is : earth
# ===================
# Number of data : 601 out of 755
# manusia
# the translation is : man
# ===================
# Number of data : 602 out of 755
# batu
# the translation is : stone
# ===================
# Number of data : 603 out of 755
# gempa
# the translation is : earthquake
# ===================
# Number of data : 604 out of 755
# bagus
# the translation is : good
# ===================
# Number of data : 605 out of 755
# tutup
# the translation is : closed
# ===================
# Number of data : 606 out of 755
# mayang
# the translation is : Mayang
# ===================
# Number of data : 607 out of 755
# mangga
# the translation is : mango
# ===================
# Number of data : 608 out of 755
# anemia
# the translation is : anemia
# ===================
# Number of data : 609 out of 755
# abang
# the translation is : brother
# ===================
# Number of data : 610 out of 755
# es
# the translation is : ice
# ===================
# Number of data : 611 out of 755
# asam
# the translation is : sour
# ===================
# Number of data : 612 out of 755
# manis
# the translation is : sweet
# ===================
# Number of data : 613 out of 755
# markas
# the translation is : Headquarters
# ===================
# Number of data : 614 out of 755
# rahasia
# the translation is : confidential
# ===================
# Number of data : 615 out of 755
# toh
# the translation is : After all
# ===================
# Number of data : 616 out of 755
# beberapa
# the translation is : a number of
# ===================
# Number of data : 617 out of 755
# suami
# the translation is : husband
# ===================
# Number of data : 618 out of 755
# cina
# the translation is : China
# ===================
# Number of data : 619 out of 755
# zodiak
# the translation is : Zodiac
# ===================
# Number of data : 620 out of 755
# zodiak
# the translation is : Zodiac
# ===================
# Number of data : 621 out of 755
# hak
# the translation is : right
# ===================
# Number of data : 622 out of 755
# lurus
# the translation is : straight
# ===================
# Number of data : 623 out of 755
# mari
# the translation is : let
# ===================
# Number of data : 624 out of 755
# bahasa
# the translation is : language
# ===================
# Number of data : 625 out of 755
# ojek
# the translation is : taxibike
# ===================
# Number of data : 626 out of 755
# agah
# the translation is : Agah
# ===================
# Number of data : 627 out of 755
# alis
# the translation is : eyebrow
# ===================
# Number of data : 628 out of 755
# islam
# the translation is : Islam
# ===================
# Number of data : 629 out of 755
# sakit
# the translation is : sick
# ===================
# Number of data : 630 out of 755
# sapu
# the translation is : broom
# ===================
# Number of data : 631 out of 755
# blender
# the translation is : Blender
# ===================
# Number of data : 632 out of 755
# ganti
# the translation is : change
# ===================
# Number of data : 633 out of 755
# hikmah
# the translation is : wisdom
# ===================
# Number of data : 634 out of 755
# nur
# the translation is : Nur
# ===================
# Number of data : 635 out of 755
# alfa
# the translation is : alpha
# ===================
# Number of data : 636 out of 755
# serius
# the translation is : are you serious
# ===================
# Number of data : 637 out of 755
# mengerti
# the translation is : understand
# ===================
# Number of data : 638 out of 755
# matematika
# the translation is : mathematics
# ===================
# Number of data : 639 out of 755
# gaya
# the translation is : style
# ===================
# Number of data : 640 out of 755
# saling
# the translation is : each other
# ===================
# Number of data : 641 out of 755
# jok
# the translation is : seat
# ===================
# Number of data : 642 out of 755
# saga
# the translation is : Saga
# ===================
# Number of data : 643 out of 755
# engkau
# the translation is : you
# ===================
# Number of data : 644 out of 755
# panci
# the translation is : pot
# ===================
# Number of data : 645 out of 755
# program
# the translation is : program
# ===================
# Number of data : 646 out of 755
# tema
# the translation is : theme
# ===================
# Number of data : 647 out of 755
# gocek
# the translation is : GOCEK
# ===================
# Number of data : 648 out of 755
# bunda
# the translation is : mother
# ===================
# Number of data : 649 out of 755
# khusus
# the translation is : special
# ===================
# Number of data : 650 out of 755
# dur
# the translation is : Dur
# ===================
# Number of data : 651 out of 755
# mereka
# the translation is : they
# ===================
# Number of data : 652 out of 755
# emosi
# the translation is : emotion
# ===================
# Number of data : 653 out of 755
# terobos
# the translation is : broken
# ===================
# Number of data : 654 out of 755
# selalu
# the translation is : always
# ===================
# Number of data : 655 out of 755
# ingat
# the translation is : remember
# ===================
# Number of data : 656 out of 755
# rute
# the translation is : route
# ===================
# Number of data : 657 out of 755
# celana
# the translation is : trousers
# ===================
# Number of data : 658 out of 755
# anu
# the translation is : Anu
# ===================
# Number of data : 659 out of 755
# resmi
# the translation is : official
# ===================
# Number of data : 660 out of 755
# jari
# the translation is : finger
# ===================
# Number of data : 661 out of 755
# burung
# the translation is : bird
# ===================
# Number of data : 662 out of 755
# lanjut
# the translation is : carry on
# ===================
# Number of data : 663 out of 755
# tokoh
# the translation is : figure
# ===================
# Number of data : 664 out of 755
# ketemu
# the translation is : meet
# ===================
# Number of data : 665 out of 755
# sebelah
# the translation is : adjacent
# ===================
# Number of data : 666 out of 755
# sebagai
# the translation is : as
# ===================
# Number of data : 667 out of 755
# taklim
# the translation is : Taklim
# ===================
# Number of data : 668 out of 755
# milik
# the translation is : owned by
# ===================
# Number of data : 669 out of 755
# mister
# the translation is : Mister
# ===================
# Number of data : 670 out of 755
# bangkit
# the translation is : rise
# ===================
# Number of data : 671 out of 755
# dokumentasi
# the translation is : documentation
# ===================
# Number of data : 672 out of 755
# segera
# the translation is : quick
# ===================
# Number of data : 673 out of 755
# profesi
# the translation is : profession
# ===================
# Number of data : 674 out of 755
# pincang
# the translation is : limp
# ===================
# Number of data : 675 out of 755
# doa
# the translation is : prayer
# ===================
# Number of data : 676 out of 755
# kondisi
# the translation is : condition
# ===================
# Number of data : 677 out of 755
# perilaku
# the translation is : behavior
# ===================
# Number of data : 678 out of 755
# sosial
# the translation is : social
# ===================
# Number of data : 679 out of 755
# kursi
# the translation is : chair
# ===================
# Number of data : 680 out of 755
# suatu
# the translation is : something
# ===================
# Number of data : 681 out of 755
# stop
# the translation is : Stop
# ===================
# Number of data : 682 out of 755
# duri
# the translation is : thorns
# ===================
# Number of data : 683 out of 755
# pala
# the translation is : nutmeg
# ===================
# Number of data : 684 out of 755
# meski
# the translation is : though
# ===================
# Number of data : 685 out of 755
# sit
# the translation is : Sit
# ===================
# Number of data : 686 out of 755
# susah
# the translation is : difficult
# ===================
# Number of data : 687 out of 755
# aduk
# the translation is : stir
# ===================
# Number of data : 688 out of 755
# peta
# the translation is : map
# ===================
# Number of data : 689 out of 755
# embek
# the translation is : Embek
# ===================
# Number of data : 690 out of 755
# tanding
# the translation is : match
# ===================
# Number of data : 691 out of 755
# perah
# the translation is : Dairy
# ===================
# Number of data : 692 out of 755
# jernih
# the translation is : clear
# ===================
# Number of data : 693 out of 755
# peluru
# the translation is : bullet
# ===================
# Number of data : 694 out of 755
# akbar
# the translation is : Akbar
# ===================
# Number of data : 695 out of 755
# teguh
# the translation is : Teguh
# ===================
# Number of data : 696 out of 755
# masa
# the translation is : times
# ===================
# Number of data : 697 out of 755
# organ
# the translation is : organ
# ===================
# Number of data : 698 out of 755
# hotel
# the translation is : hotel
# ===================
# Number of data : 699 out of 755
# ma
# the translation is : Ma
# ===================
# Number of data : 700 out of 755
# monitor
# the translation is : monitor
# ===================
# Number of data : 701 out of 755
# tah
# the translation is : tah
# ===================
# Number of data : 702 out of 755
# maraton
# the translation is : marathon
# ===================
# Number of data : 703 out of 755
# hadir
# the translation is : present
# ===================
# Number of data : 704 out of 755
# balon
# the translation is : balloon
# ===================
# Number of data : 705 out of 755
# pulang
# the translation is : go home
# ===================
# Number of data : 706 out of 755
# lalu
# the translation is : then
# ===================
# Number of data : 707 out of 755
# bolong
# the translation is : perforated
# ===================
# Number of data : 708 out of 755
# tetap
# the translation is : permanent
# ===================
# Number of data : 709 out of 755
# setia
# the translation is : loyal
# ===================
# Number of data : 710 out of 755
# inisiator
# the translation is : Initiator
# ===================
# Number of data : 711 out of 755
# sela
# the translation is : interrupt
# ===================
# Number of data : 712 out of 755
# zat
# the translation is : substance
# ===================
# Number of data : 713 out of 755
# zat
# the translation is : substance
# ===================
# Number of data : 714 out of 755
# batas
# the translation is : limit
# ===================
# Number of data : 715 out of 755
# seluruh
# the translation is : all
# ===================
# Number of data : 716 out of 755
# bunga
# the translation is : flower
# ===================
# Number of data : 717 out of 755
# ruang
# the translation is : room
# ===================
# Number of data : 718 out of 755
# makanya
# the translation is : so
# ===================
# Number of data : 719 out of 755
# biliar
# the translation is : Billiard
# ===================
# Number of data : 720 out of 755
# sok
# the translation is : pretentious
# ===================
# Number of data : 721 out of 755
# turus
# the translation is : Turus
# ===================
# Number of data : 722 out of 755
# kode
# the translation is : code
# ===================
# Number of data : 723 out of 755
# nu
# the translation is : NU
# ===================
# Number of data : 724 out of 755
# objektif
# the translation is : objective
# ===================
# Number of data : 725 out of 755
# penting
# the translation is : important
# ===================
# Number of data : 726 out of 755
# bila
# the translation is : when
# ===================
# Number of data : 727 out of 755
# kecuali
# the translation is : except
# ===================
# Number of data : 728 out of 755
# sah
# the translation is : legitimate
# ===================
# Number of data : 729 out of 755
# nadi
# the translation is : pulse
# ===================
# Number of data : 730 out of 755
# kejar
# the translation is : Chase
# ===================
# Number of data : 731 out of 755
# cermai
# the translation is : Cermai
# ===================
# Number of data : 732 out of 755
# pusing
# the translation is : dizzy
# ===================
# Number of data : 733 out of 755
# neutron
# the translation is : Neutron
# ===================
# Number of data : 734 out of 755
# nyaris
# the translation is : almost
# ===================
# Number of data : 735 out of 755
# aksi
# the translation is : action
# ===================
# Number of data : 736 out of 755
# kagak
# the translation is : not
# ===================
# Number of data : 737 out of 755
# muara
# the translation is : estuary
# ===================
# Number of data : 738 out of 755
# ujung
# the translation is : end
# ===================
# Number of data : 739 out of 755
# mirip
# the translation is : similar
# ===================
# Number of data : 740 out of 755
# lori
# the translation is : Lori
# ===================
# Number of data : 741 out of 755
# kak
# the translation is : Sis
# ===================
# Number of data : 742 out of 755
# lain
# the translation is : other
# ===================
# Number of data : 743 out of 755
# pilih
# the translation is : select
# ===================
# Number of data : 744 out of 755
# pa
# the translation is : Pa
# ===================
# Number of data : 745 out of 755
# kuat
# the translation is : strong
# ===================
# Number of data : 746 out of 755
# kena
# the translation is : hit
# ===================
# Number of data : 747 out of 755
# paya
# the translation is : Paya
# ===================
# Number of data : 748 out of 755
# nikah
# the translation is : marry
# ===================
# Number of data : 749 out of 755
# tangan
# the translation is : hand
# ===================
# Number of data : 750 out of 755
# cuci
# the translation is : wash
# ===================
# Number of data : 751 out of 755
# hebat
# the translation is : great
# ===================
# Number of data : 752 out of 755
# lucah
# the translation is : Lucah
# ===================
# Number of data : 753 out of 755
# obyek
# the translation is : object
# ===================
# Number of data : 754 out of 755
# man
# the translation is : Man

# %%
df.to_csv("Translated all legal words "+ video_id)
